# %%
import pandas as pd
from tabulate import tabulate

df = pd.read_csv('https://raw.githubusercontent.com/ricardoahumada/DataScienceBasics/refs/heads/main/data/titanic.csv')
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    object
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    object
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
#  15  Unnamed: 15  0 non-null      float64
# dtypes: bool(2), float64(3), int64(4), object(7)
# memory usage: 99.3+ KB
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone  Unnamed: 15
# 0    man        True  NaN  Southampton    no  False          NaN
# 1  woman       False    C    Cherbourg   yes  False          NaN
# 2  woman       False  NaN  Southampton   yes   True          NaN
# 3  woman       False    C  Southampton   yes  False          NaN
# 4    man        True  NaN  Southampton    no   True          NaN

# %%
df['cage'] = pd.cut(df['age'],[0,10,30,60,80])
df.pop('Unnamed: 15')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone      cage
# 0    man        True  NaN  Southampton    no  False  (10, 30]
# 1  woman       False    C    Cherbourg   yes  False  (30, 60]
# 2  woman       False  NaN  Southampton   yes   True  (10, 30]
# 3  woman       False    C  Southampton   yes  False  (30, 60]
# 4    man        True  NaN  Southampton    no   True  (30, 60]

# %%
pcdf = df.pivot(columns='class', values='survived')
ndf = pd.concat([df,pcdf], axis=1)
ndf
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone          cage  First  \
# 0      man        True  NaN  Southampton    no  False  (10.0, 30.0]    NaN
# 1    woman       False    C    Cherbourg   yes  False  (30.0, 60.0]    1.0
# 2    woman       False  NaN  Southampton   yes   True  (10.0, 30.0]    NaN
# 3    woman       False    C  Southampton   yes  False  (30.0, 60.0]    1.0
# 4      man        True  NaN  Southampton    no   True  (30.0, 60.0]    NaN
# ..     ...         ...  ...          ...   ...    ...           ...    ...
# 886    man        True  NaN  Southampton    no   True  (10.0, 30.0]    NaN
# 887  woman       False    B  Southampton   yes   True  (10.0, 30.0]    1.0
# 888  woman       False  NaN  Southampton    no  False           NaN    NaN
# 889    man        True    C    Cherbourg   yes   True  (10.0, 30.0]    1.0
# 890    man        True  NaN   Queenstown    no   True  (30.0, 60.0]    NaN
#
#      Second  Third
# 0       NaN    0.0
# 1       NaN    NaN
# 2       NaN    1.0
# 3       NaN    NaN
# 4       NaN    0.0
# ..      ...    ...
# 886     0.0    NaN
# 887     NaN    NaN
# 888     NaN    0.0
# 889     NaN    NaN
# 890     NaN    0.0
#
# [891 rows x 19 columns]

# %%
ndf.groupby(['sex','cage']).agg({'First': 'count', 'Second': 'count', 'Third': 'count'})
# Out:
#                  First  Second  Third
# sex    cage
# female (0, 10]       1       8     22
#        (10, 30]     34      36     57
#        (30, 60]     48      30     22
#        (60, 80]      2       0      1
# male   (0, 10]       2       9     22
#        (10, 30]     24      43    151
#        (30, 60]     63      44     76
#        (60, 80]     12       3      4

# %% [markdown]
# 6. Escribe un programa Pandas para extraer información sobre el número de compras totales y el monto total por nombre de producto y año.

# %%
df_purch = pd.read_excel('Users/Data.jalda/FoodMarket.xlsx', sheet_name='Purchases')
df_purch.info()
print(df_purch.head())
print(df_purch.tail())
df_purch.describe()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df_purch = pd.read_excel('Users/Data.jalda/FoodMarket.xlsx', sheet_name='Purchases')
#       2 df_purch.info()
#       3 print(df_purch.head())
#
# File /anaconda/envs/azureml_py38/lib/python3.10/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File /anaconda/envs/azureml_py38/lib/python3.10/site-packages/pandas/io/excel/_base.py:364, in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     362 if not isinstance(io, ExcelFile):
#     363     should_close = True
# --> 364     io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     365 elif engine and engine != io.engine:
#     366     raise ValueError(
#     367         "Engine should not be specified when passing "
#     368         "an ExcelFile - ExcelFile already has the engine set"
#     369     )
#
# File /anaconda/envs/azureml_py38/lib/python3.10/site-packages/pandas/io/excel/_base.py:1233, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options)
#    1230 self.engine = engine
#    1231 self.storage_options = storage_options
# -> 1233 self._reader = self._engines[engine](self._io, storage_options=storage_options)
#
# File /anaconda/envs/azureml_py38/lib/python3.10/site-packages/pandas/io/excel/_openpyxl.py:521, in OpenpyxlReader.__init__(self, filepath_or_buffer, storage_options)
#     506 def __init__(
#     507     self,
#     508     filepath_or_buffer: FilePathOrBuffer,
#     509     storage_options: StorageOptions = None,
#     510 ) -> None:
#     511     """
#     512     Reader using openpyxl engine.
#     513
#    (...)
#     519         passed to fsspec for appropriate URLs (see ``_get_filepath_or_buffer``)
#     520     """
# --> 521     import_optional_dependency("openpyxl")
#     522     super().__init__(filepath_or_buffer, storage_options=storage_options)
#
# File /anaconda/envs/azureml_py38/lib/python3.10/site-packages/pandas/compat/_optional.py:118, in import_optional_dependency(name, extra, errors, min_version)
#     116 except ImportError:
#     117     if errors == "raise":
# --> 118         raise ImportError(msg) from None
#     119     else:
#     120         return None
#
# ImportError: Missing optional dependency 'openpyxl'.  Use pip or conda to install openpyxl.

# %% [markdown]
# ### VALORES DUPLICADOS

# %%
# duplicates
data = {'customer_id': [102, 102, 101, 103, 102], 'product_id': [
    'A', 'B', 'A', 'C', 'B'], 'quantity_sold': [5, 3, 2, 1, 4]}
df = pd.DataFrame(data)

# %% [markdown]
# ### Perfilado

# %%
df = pd.read_csv('https://raw.githubusercontent.com/ricardoahumada/DataScienceBasics/refs/heads/main/data/housing.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
df.tail()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND

# %%
df.shape
# Out:
# (20640, 10)

# %%
df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# 25%        296.000000    787.000000    280.000000       2.563400
# 50%        435.000000   1166.000000    409.000000       3.534800
# 75%        647.000000   1725.000000    605.000000       4.743250
# max       6445.000000  35682.000000   6082.000000      15.000100
#
#        median_house_value
# count        20640.000000
# mean        206855.816909
# std         115395.615874
# min          14999.000000
# 25%         119600.000000
# 50%         179700.000000
# 75%         264725.000000
# max         500001.000000

# %%
df.describe(include='object')
# Out:
#        ocean_proximity
# count            20640
# unique               5
# top          <1H OCEAN
# freq              9136

# %%
df_group = df.groupby('ocean_proximity')['population'].mean()
df_group
# Out:
# ocean_proximity
# <1H OCEAN     1520.290499
# INLAND        1391.046252
# ISLAND         668.000000
# NEAR BAY      1230.317467
# NEAR OCEAN    1354.008653
# Name: population, dtype: float64

# %%
df.sort_values(by='median_income', ascending=False)[['median_income','total_rooms','total_bedrooms','population','households']].head()
# Out:
#        median_income  total_rooms  total_bedrooms  population  households
# 4352         15.0001        407.0            67.0       100.0        47.0
# 10673        15.0001       5192.0           658.0      1865.0       662.0
# 8849         15.0001       3815.0           439.0      1266.0       413.0
# 4606         15.0001       1482.0           171.0       531.0       161.0
# 5257         15.0001       2861.0           360.0       829.0       310.0

# %%
df['ocean_proximity'].value_counts()
# Out:
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: ocean_proximity, dtype: int64
